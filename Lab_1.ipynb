# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = [1, 10, 1000]
np.log(np.exp(1 / (np.sin(x) +1))/(5/4 + 1/(np.power(x, 15)))) / np.log(1 + np.power(x, 2))
# Out:
# array([-0.38647794,  0.42684485,  0.02346912])

# %%
x = np.arange(-2.5, 5, 0.1)
plt.plot(x, x**2, label=r'$f_1(x)=x^2$')
plt.plot(x, 2*x + 3, label=r'$f_2(x)=2x+3$')
plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$f(x)$', fontsize=14)
plt.grid(True)
plt.legend(loc='best', fontsize=12)
plt.savefig('figure_with_legend.png')
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
t = np.arange(-10, 11, 1)

#subplot 1
sp = plt.subplot(221)
plt.plot(x, np.sin(x))
plt.title(r'$\sin(x)$')
plt.grid(True)

#subplot 2
sp = plt.subplot(222)
plt.plot(x, np.cos(x), 'g')
plt.axis('equal')
plt.title(r'$\cos(x)$')
plt.grid(True)

#subplot 3
sp = plt.subplot(223)
plt.plot(x, x ** 2, t, t ** 2, 'ro')
plt.title(r'$x^2$')

#subplot 4
sp = plt.subplot(224)
plt.plot(x, x)
sp.spines['left'].set_position('center')
sp.spines['bottom'].set_position('center')
plt.title(r'$x$')

plt.show()

# %%
plt.subplot(111, polar=True)
phi = np.arange(0, 2*np.pi, 0.01)
rho = 2*phi
plt.plot(phi, rho, color='black', lw=5)
plt.show()

# %%
t = np.arange(0, 2*np.pi, 0.01)
r = 4
plt.plot(r*np.sin(t), r*np.cos(t), lw=3)
plt.axis('equal')
plt.show()

# %%
from mpl_toolkits.mplot3d import axes3d
ax = axes3d.Axes3D(plt.figure())
i = np.arange(-1, 1, 0.01)
x, y = np.meshgrid(i, i)
z = x**2 - y**2
ax.plot_wireframe(x, y, z, rstride=30, cstride=5)
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)
#The histogram of the data
n, bins, patches = plt.hist(x, 50, density=True, facecolor='g', alpha=0.75)

plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .028, r'$\mu=100,\ \sigma=15$')
plt.text(50, .033, r'$\varpi_{\mu,\sigma^2}(x) = \frac{1}{\sigma\sqrt{2\pi}} \,e^{ -\frac{(x- \mu)^2}{2\sigma^2}} = \frac{1}{\sigma} \varphi\left(\frac{x - \mu}{\sigma}\right),\quad x\in\mathbb{R}$', fontsize=14, color='red')
plt.axis([40, 160, 0, 0.04])
plt.grid(True)
plt.show()

# %%
plt.plot(np.arange(1, 101, 1), np.random.randint(1, 10, 100), 'ro')
plt.show()

# %%
np.arange(1, 5, 1)
# Out:
# array([1, 2, 3, 4])
